# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
weather_data = pd.read_csv("Boise_rainfall_stats.csv", skipfooter = 3, skiprows = 0, header = 1, engine = "python", index_col = "Date", parse_dates = ["Date"], usecols = [0,2,5,8,11,14,16])

# %%
source1 = pd.read_csv("Boise_rainfall_stats.csv")
source1.iloc[-1,0]
# Out:
# 'Boise, ID Weather History | Weather Underground (wunderground.com) https://www.wunderground.com/history/monthly/us/id/boise/KBOI/date/2022-9'

# %%
weather_data.head(2)
# Out:
#              Avg  Avg.1  Avg.2  Avg.3  Avg.4  Total
# Date
# 2020-09-01  66.8   41.3   42.6    5.8   27.1    0.0
# 2020-09-02  76.3   41.9   32.8    6.0   27.1    0.0

# %%
weather_data.rename(columns = {'Date':'Date', 'Avg':'Temp_Avg', 'Avg.1':'Dew_Pt_Avg', 'Avg.2':'Humidity_Avg', 'Avg.3':'Wind_Speed_Avg', 'Avg.4':'Pressure_Avg', 'Total':'Precipitation'}, inplace = True)

# %%
weather_data
# Out:
#             Temp_Avg  Dew_Pt_Avg  Humidity_Avg  Wind_Speed_Avg  Pressure_Avg  \
# Date
# 2020-09-01      66.8        41.3          42.6             5.8          27.1
# 2020-09-02      76.3        41.9          32.8             6.0          27.1
# 2020-09-03      77.4        40.5          28.3             6.4          27.1
# 2020-09-04      82.2        37.9          23.3             7.2          27.1
# 2020-09-05      82.6        38.2          22.1             7.2          27.1
# ...              ...         ...           ...             ...           ...
# 2022-09-11      70.3        27.9          22.8             6.6          27.1
# 2022-09-12      70.9        30.2          22.8             7.0          27.0
# 2022-09-13      69.1        49.5          51.2             7.0          26.9
# 2022-09-14      69.2        51.2          55.5             4.8          26.9
# 2022-09-15      70.9        49.0          47.5             6.0          26.9
#
#             Precipitation
# Date
# 2020-09-01           0.00
# 2020-09-02           0.00
# 2020-09-03           0.00
# 2020-09-04           0.00
# 2020-09-05           0.00
# ...                   ...
# 2022-09-11           0.00
# 2022-09-12           0.00
# 2022-09-13           0.00
# 2022-09-14           0.07
# 2022-09-15           0.00
#
# [745 rows x 6 columns]

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 745 entries, 2020-09-01 to 2022-09-15
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Temp_Avg        745 non-null    float64
#  1   Dew_Pt_Avg      745 non-null    float64
#  2   Humidity_Avg    745 non-null    float64
#  3   Wind_Speed_Avg  745 non-null    float64
#  4   Pressure_Avg    745 non-null    float64
#  5   Precipitation   744 non-null    float64
# dtypes: float64(6)
# memory usage: 40.7 KB

# %%
moon = pd.read_excel("Moon_Phases_rev.xlsx", header = None, skipfooter = 2, names = ["Date", "Moon_Phase"])
moon.head()
# Out:
#         Date     Moon_Phase
# 0 2020-08-18       New Moon
# 1 2020-08-25  First Quarter
# 2 2020-09-01      Full Moon
# 3 2020-09-10  Third Quarter
# 4 2020-09-17       New Moon

# %%
source2 = pd.read_excel("Moon_Phases_rev.xlsx")
source2.iloc[-1,0]
# Out:
# 'Moon Phases 2022 – Lunar Calendar for Boise, Idaho, USA (timeanddate.com)'

# %%
moon.set_index("Date", inplace = True)
moon.head()
# Out:
#                Moon_Phase
# Date
# 2020-08-18       New Moon
# 2020-08-25  First Quarter
# 2020-09-01      Full Moon
# 2020-09-10  Third Quarter
# 2020-09-17       New Moon

# %%
moon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 108 entries, 2020-08-18 to 2022-10-17
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Moon_Phase  108 non-null    object
# dtypes: object(1)
# memory usage: 1.7+ KB

# %%
weather_data = pd.merge(weather_data, moon, how = "outer", right_index = True, left_index = True)
weather_data
# Out:
#             Temp_Avg  Dew_Pt_Avg  Humidity_Avg  Wind_Speed_Avg  Pressure_Avg  \
# Date
# 2020-08-18       NaN         NaN           NaN             NaN           NaN
# 2020-08-25       NaN         NaN           NaN             NaN           NaN
# 2020-09-01      66.8        41.3          42.6             5.8          27.1
# 2020-09-02      76.3        41.9          32.8             6.0          27.1
# 2020-09-03      77.4        40.5          28.3             6.4          27.1
# ...              ...         ...           ...             ...           ...
# 2022-09-17       NaN         NaN           NaN             NaN           NaN
# 2022-09-25       NaN         NaN           NaN             NaN           NaN
# 2022-10-02       NaN         NaN           NaN             NaN           NaN
# 2022-10-09       NaN         NaN           NaN             NaN           NaN
# 2022-10-17       NaN         NaN           NaN             NaN           NaN
#
#             Precipitation     Moon_Phase
# Date
# 2020-08-18            NaN       New Moon
# 2020-08-25            NaN  First Quarter
# 2020-09-01            0.0      Full Moon
# 2020-09-02            0.0            NaN
# 2020-09-03            0.0            NaN
# ...                   ...            ...
# 2022-09-17            NaN  Third Quarter
# 2022-09-25            NaN       New Moon
# 2022-10-02            NaN  First Quarter
# 2022-10-09            NaN      Full Moon
# 2022-10-17            NaN  Third Quarter
#
# [752 rows x 7 columns]

# %%
weather_data = weather_data.iloc[2:]

# %%
weather_data.head(5)
# Out:
#             Temp_Avg  Dew_Pt_Avg  Humidity_Avg  Wind_Speed_Avg  Pressure_Avg  \
# Date
# 2020-09-01      66.8        41.3          42.6             5.8          27.1
# 2020-09-02      76.3        41.9          32.8             6.0          27.1
# 2020-09-03      77.4        40.5          28.3             6.4          27.1
# 2020-09-04      82.2        37.9          23.3             7.2          27.1
# 2020-09-05      82.6        38.2          22.1             7.2          27.1
#
#             Precipitation Moon_Phase
# Date
# 2020-09-01            0.0  Full Moon
# 2020-09-02            0.0        NaN
# 2020-09-03            0.0        NaN
# 2020-09-04            0.0        NaN
# 2020-09-05            0.0        NaN

# %%
weather_data.loc[:,"Moon_Phase"] = weather_data.loc[:,"Moon_Phase"].ffill()
weather_data
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#             Temp_Avg  Dew_Pt_Avg  Humidity_Avg  Wind_Speed_Avg  Pressure_Avg  \
# Date
# 2020-09-01      66.8        41.3          42.6             5.8          27.1
# 2020-09-02      76.3        41.9          32.8             6.0          27.1
# 2020-09-03      77.4        40.5          28.3             6.4          27.1
# 2020-09-04      82.2        37.9          23.3             7.2          27.1
# 2020-09-05      82.6        38.2          22.1             7.2          27.1
# ...              ...         ...           ...             ...           ...
# 2022-09-17       NaN         NaN           NaN             NaN           NaN
# 2022-09-25       NaN         NaN           NaN             NaN           NaN
# 2022-10-02       NaN         NaN           NaN             NaN           NaN
# 2022-10-09       NaN         NaN           NaN             NaN           NaN
# 2022-10-17       NaN         NaN           NaN             NaN           NaN
#
#             Precipitation     Moon_Phase
# Date
# 2020-09-01            0.0      Full Moon
# 2020-09-02            0.0      Full Moon
# 2020-09-03            0.0      Full Moon
# 2020-09-04            0.0      Full Moon
# 2020-09-05            0.0      Full Moon
# ...                   ...            ...
# 2022-09-17            NaN  Third Quarter
# 2022-09-25            NaN       New Moon
# 2022-10-02            NaN  First Quarter
# 2022-10-09            NaN      Full Moon
# 2022-10-17            NaN  Third Quarter
#
# [750 rows x 7 columns]

# %%
one_hot = pd.get_dummies(weather_data["Moon_Phase"], drop_first = True)
one_hot
# Out:
#             Full Moon  New Moon  Third Quarter
# Date
# 2020-09-01          1         0              0
# 2020-09-02          1         0              0
# 2020-09-03          1         0              0
# 2020-09-04          1         0              0
# 2020-09-05          1         0              0
# ...               ...       ...            ...
# 2022-09-17          0         0              1
# 2022-09-25          0         1              0
# 2022-10-02          0         0              0
# 2022-10-09          1         0              0
# 2022-10-17          0         0              1
#
# [750 rows x 3 columns]

# %%
weather_data = weather_data.drop("Moon_Phase", axis =1)

# %%
weather_data = weather_data.join(one_hot)

# %%
weather_data
# Out:
#             Temp_Avg  Dew_Pt_Avg  Humidity_Avg  Wind_Speed_Avg  Pressure_Avg  \
# Date
# 2020-09-01      66.8        41.3          42.6             5.8          27.1
# 2020-09-02      76.3        41.9          32.8             6.0          27.1
# 2020-09-03      77.4        40.5          28.3             6.4          27.1
# 2020-09-04      82.2        37.9          23.3             7.2          27.1
# 2020-09-05      82.6        38.2          22.1             7.2          27.1
# ...              ...         ...           ...             ...           ...
# 2022-09-17       NaN         NaN           NaN             NaN           NaN
# 2022-09-25       NaN         NaN           NaN             NaN           NaN
# 2022-10-02       NaN         NaN           NaN             NaN           NaN
# 2022-10-09       NaN         NaN           NaN             NaN           NaN
# 2022-10-17       NaN         NaN           NaN             NaN           NaN
#
#             Precipitation  Full Moon  New Moon  Third Quarter
# Date
# 2020-09-01            0.0          1         0              0
# 2020-09-02            0.0          1         0              0
# 2020-09-03            0.0          1         0              0
# 2020-09-04            0.0          1         0              0
# 2020-09-05            0.0          1         0              0
# ...                   ...        ...       ...            ...
# 2022-09-17            NaN          0         0              1
# 2022-09-25            NaN          0         1              0
# 2022-10-02            NaN          0         0              0
# 2022-10-09            NaN          1         0              0
# 2022-10-17            NaN          0         0              1
#
# [750 rows x 9 columns]

# %%
sunspot_num = pd.read_excel("Sunspot_Number.xlsx", skipfooter = 2, header = 0, usecols = [0,5], parse_dates = True, index_col = "Date")#, index_col = "D)

# %%
source3 = pd.read_excel("Sunspot_Number.xlsx")
source3.iloc[-1,0]
# Out:
# 'Source:  https://www.sidc.be/silso/datafiles#total'

# %%
sunspot_num.rename(columns = {"Total Number":"Sunspot_Number"}, inplace = True)

# %%
sunspot_num
# Out:
#             Sunspot_Number
# Date
# 2020-09-01               0
# 2020-09-02               0
# 2020-09-03               0
# 2020-09-04               0
# 2020-09-05               0
# ...                    ...
# 2022-08-27              94
# 2022-08-28              85
# 2022-08-29              71
# 2022-08-30              49
# 2022-08-31              44
#
# [730 rows x 1 columns]

# %%
sunspot_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 730 entries, 2020-09-01 to 2022-08-31
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sunspot_Number  730 non-null    int64
# dtypes: int64(1)
# memory usage: 11.4 KB

# %%
weather_data = pd.merge(weather_data, sunspot_num, how = "outer", right_index = True, left_index = True)
weather_data.tail(25)
# Out:
#             Temp_Avg  Dew_Pt_Avg  Humidity_Avg  Wind_Speed_Avg  Pressure_Avg  \
# Date
# 2022-08-27      74.5        42.8          33.5             7.8          26.9
# 2022-08-28      69.5        31.9          27.2             6.0          26.9
# 2022-08-29      76.6        35.3          24.6             4.6          27.0
# 2022-08-30      81.2        38.5          23.8             6.0          27.1
# 2022-08-31      87.3        37.2          18.7             6.8          27.0
# 2022-09-01      80.7        36.3          25.1             5.8          27.0
# 2022-09-02      81.6        22.0          13.8             6.0          27.0
# 2022-09-03      84.3        29.5          14.9             7.8          27.0
# 2022-09-04      79.3        37.0          25.3             5.3          27.0
# 2022-09-05      78.0        34.1          21.6             6.0          27.0
# 2022-09-06      81.2        37.3          21.8             5.5          27.0
# 2022-09-07      85.7        39.1          21.4             8.6          27.0
# 2022-09-08      73.8        30.6          26.1            10.6          27.0
# 2022-09-09      62.4        25.7          27.4             4.4          27.0
# 2022-09-10      66.4        27.1          23.8             7.6          27.1
# 2022-09-11      70.3        27.9          22.8             6.6          27.1
# 2022-09-12      70.9        30.2          22.8             7.0          27.0
# 2022-09-13      69.1        49.5          51.2             7.0          26.9
# 2022-09-14      69.2        51.2          55.5             4.8          26.9
# 2022-09-15      70.9        49.0          47.5             6.0          26.9
# 2022-09-17       NaN         NaN           NaN             NaN           NaN
# 2022-09-25       NaN         NaN           NaN             NaN           NaN
# 2022-10-02       NaN         NaN           NaN             NaN           NaN
# 2022-10-09       NaN         NaN           NaN             NaN           NaN
# 2022-10-17       NaN         NaN           NaN             NaN           NaN
#
#             Precipitation  Full Moon  New Moon  Third Quarter  Sunspot_Number
# Date
# 2022-08-27           0.00          0         1              0            94.0
# 2022-08-28           0.00          0         1              0            85.0
# 2022-08-29           0.00          0         1              0            71.0
# 2022-08-30           0.00          0         1              0            49.0
# 2022-08-31           0.00          0         1              0            44.0
# 2022-09-01           0.00          0         1              0             NaN
# 2022-09-02           0.00          0         1              0             NaN
# 2022-09-03           0.00          0         0              0             NaN
# 2022-09-04           0.00          0         0              0             NaN
# 2022-09-05           0.00          0         0              0             NaN
# 2022-09-06           0.00          0         0              0             NaN
# 2022-09-07           0.00          0         0              0             NaN
# 2022-09-08           0.00          0         0              0             NaN
# 2022-09-09           0.00          0         0              0             NaN
# 2022-09-10           0.00          1         0              0             NaN
# 2022-09-11           0.00          1         0              0             NaN
# 2022-09-12           0.00          1         0              0             NaN
# 2022-09-13           0.00          1         0              0             NaN
# 2022-09-14           0.07          1         0              0             NaN
# 2022-09-15           0.00          1         0              0             NaN
# 2022-09-17            NaN          0         0              1             NaN
# 2022-09-25            NaN          0         1              0             NaN
# 2022-10-02            NaN          0         0              0             NaN
# 2022-10-09            NaN          1         0              0             NaN
# 2022-10-17            NaN          0         0              1             NaN

# %%
mean_ss = weather_data.Sunspot_Number.mean()
mean_ss = round(mean_ss,0)

# %%
weather_data.loc[:,"Sunspot_Number"] = weather_data.loc[:,"Sunspot_Number"].fillna(mean_ss)
weather_data
# Out:
#             Temp_Avg  Dew_Pt_Avg  Humidity_Avg  Wind_Speed_Avg  Pressure_Avg  \
# Date
# 2020-09-01      66.8        41.3          42.6             5.8          27.1
# 2020-09-02      76.3        41.9          32.8             6.0          27.1
# 2020-09-03      77.4        40.5          28.3             6.4          27.1
# 2020-09-04      82.2        37.9          23.3             7.2          27.1
# 2020-09-05      82.6        38.2          22.1             7.2          27.1
# ...              ...         ...           ...             ...           ...
# 2022-09-17       NaN         NaN           NaN             NaN           NaN
# 2022-09-25       NaN         NaN           NaN             NaN           NaN
# 2022-10-02       NaN         NaN           NaN             NaN           NaN
# 2022-10-09       NaN         NaN           NaN             NaN           NaN
# 2022-10-17       NaN         NaN           NaN             NaN           NaN
#
#             Precipitation  Full Moon  New Moon  Third Quarter  Sunspot_Number
# Date
# 2020-09-01            0.0          1         0              0             0.0
# 2020-09-02            0.0          1         0              0             0.0
# 2020-09-03            0.0          1         0              0             0.0
# 2020-09-04            0.0          1         0              0             0.0
# 2020-09-05            0.0          1         0              0             0.0
# ...                   ...        ...       ...            ...             ...
# 2022-09-17            NaN          0         0              1            43.0
# 2022-09-25            NaN          0         1              0            43.0
# 2022-10-02            NaN          0         0              0            43.0
# 2022-10-09            NaN          1         0              0            43.0
# 2022-10-17            NaN          0         0              1            43.0
#
# [750 rows x 10 columns]

# %%
weather_data = weather_data.iloc[0:-5,:]
weather_data
# Out:
#             Temp_Avg  Dew_Pt_Avg  Humidity_Avg  Wind_Speed_Avg  Pressure_Avg  \
# Date
# 2020-09-01      66.8        41.3          42.6             5.8          27.1
# 2020-09-02      76.3        41.9          32.8             6.0          27.1
# 2020-09-03      77.4        40.5          28.3             6.4          27.1
# 2020-09-04      82.2        37.9          23.3             7.2          27.1
# 2020-09-05      82.6        38.2          22.1             7.2          27.1
# ...              ...         ...           ...             ...           ...
# 2022-09-07      85.7        39.1          21.4             8.6          27.0
# 2022-09-08      73.8        30.6          26.1            10.6          27.0
# 2022-09-09      62.4        25.7          27.4             4.4          27.0
# 2022-09-10      66.4        27.1          23.8             7.6          27.1
# 2022-09-11      70.3        27.9          22.8             6.6          27.1
#
#             Precipitation  Full Moon  New Moon  Third Quarter  Sunspot_Number
# Date
# 2020-09-01            0.0          1         0              0             0.0
# 2020-09-02            0.0          1         0              0             0.0
# 2020-09-03            0.0          1         0              0             0.0
# 2020-09-04            0.0          1         0              0             0.0
# 2020-09-05            0.0          1         0              0             0.0
# ...                   ...        ...       ...            ...             ...
# 2022-09-07            0.0          0         0              0            43.0
# 2022-09-08            0.0          0         0              0            43.0
# 2022-09-09            0.0          0         0              0            43.0
# 2022-09-10            0.0          1         0              0            43.0
# 2022-09-11            0.0          1         0              0            43.0
#
# [741 rows x 10 columns]

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 741 entries, 2020-09-01 to 2022-09-11
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Temp_Avg        741 non-null    float64
#  1   Dew_Pt_Avg      741 non-null    float64
#  2   Humidity_Avg    741 non-null    float64
#  3   Wind_Speed_Avg  741 non-null    float64
#  4   Pressure_Avg    741 non-null    float64
#  5   Precipitation   740 non-null    float64
#  6   Full Moon       741 non-null    uint8
#  7   New Moon        741 non-null    uint8
#  8   Third Quarter   741 non-null    uint8
#  9   Sunspot_Number  741 non-null    float64
# dtypes: float64(7), uint8(3)
# memory usage: 48.5 KB

# %%
#This fills in all the null values with the average
# def fill_nan(df):
#     for col in df.columns[df.isnull().any(axis=0)]:
#         df[col].fillna(weather_data[col].mean(),inplace=True)
#     return round(df,0)

# weather_data = fill_nan(weather_data)

# %%
weather_data.to_csv("Boise_rainfall_data.csv")

# %%
weather_data.Precipitation.loc[weather_data.Precipitation > 0]
# Out:
# Date
# 2020-09-26    1.0
# 2020-10-11    1.0
# 2020-10-25    1.0
# 2020-11-02    1.0
# 2020-11-05    1.0
#              ...
# 2022-07-11    1.0
# 2022-07-20    1.0
# 2022-08-03    1.0
# 2022-08-11    1.0
# 2022-08-20    1.0
# Name: Precipitation, Length: 154, dtype: float64

# %%
weather_data.loc[weather_data.Precipitation > 0, "Precipitation"] = 1
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
weather_data
# Out:
#             Temp_Avg  Dew_Pt_Avg  Humidity_Avg  Wind_Speed_Avg  Pressure_Avg  \
# Date
# 2020-09-01      66.8        41.3          42.6             5.8          27.1
# 2020-09-02      76.3        41.9          32.8             6.0          27.1
# 2020-09-03      77.4        40.5          28.3             6.4          27.1
# 2020-09-04      82.2        37.9          23.3             7.2          27.1
# 2020-09-05      82.6        38.2          22.1             7.2          27.1
# ...              ...         ...           ...             ...           ...
# 2022-09-07      85.7        39.1          21.4             8.6          27.0
# 2022-09-08      73.8        30.6          26.1            10.6          27.0
# 2022-09-09      62.4        25.7          27.4             4.4          27.0
# 2022-09-10      66.4        27.1          23.8             7.6          27.1
# 2022-09-11      70.3        27.9          22.8             6.6          27.1
#
#             Precipitation  Full Moon  New Moon  Third Quarter  Sunspot_Number
# Date
# 2020-09-01            0.0          1         0              0             0.0
# 2020-09-02            0.0          1         0              0             0.0
# 2020-09-03            0.0          1         0              0             0.0
# 2020-09-04            0.0          1         0              0             0.0
# 2020-09-05            0.0          1         0              0             0.0
# ...                   ...        ...       ...            ...             ...
# 2022-09-07            0.0          0         0              0            43.0
# 2022-09-08            0.0          0         0              0            43.0
# 2022-09-09            0.0          0         0              0            43.0
# 2022-09-10            0.0          1         0              0            43.0
# 2022-09-11            0.0          1         0              0            43.0
#
# [741 rows x 10 columns]

# %%
#From here on down I need to evaluate the results.  Data is now for two years.  Why is it showing rain less
#in two years than one year before

# %%
weather_data.Precipitation.loc[weather_data.Precipitation == 1].sum()
# Out:
# 154.0

# %%
weather_data
# Out:
#             Temp_Avg  Dew_Pt_Avg  Humidity_Avg  Wind_Speed_Avg  Pressure_Avg  \
# Date
# 2020-09-01      66.8        41.3          42.6             5.8          27.1
# 2020-09-02      76.3        41.9          32.8             6.0          27.1
# 2020-09-03      77.4        40.5          28.3             6.4          27.1
# 2020-09-04      82.2        37.9          23.3             7.2          27.1
# 2020-09-05      82.6        38.2          22.1             7.2          27.1
# ...              ...         ...           ...             ...           ...
# 2022-09-07      85.7        39.1          21.4             8.6          27.0
# 2022-09-08      73.8        30.6          26.1            10.6          27.0
# 2022-09-09      62.4        25.7          27.4             4.4          27.0
# 2022-09-10      66.4        27.1          23.8             7.6          27.1
# 2022-09-11      70.3        27.9          22.8             6.6          27.1
#
#             Precipitation  Full Moon  New Moon  Third Quarter  Sunspot_Number
# Date
# 2020-09-01            0.0          1         0              0             0.0
# 2020-09-02            0.0          1         0              0             0.0
# 2020-09-03            0.0          1         0              0             0.0
# 2020-09-04            0.0          1         0              0             0.0
# 2020-09-05            0.0          1         0              0             0.0
# ...                   ...        ...       ...            ...             ...
# 2022-09-07            0.0          0         0              0            43.0
# 2022-09-08            0.0          0         0              0            43.0
# 2022-09-09            0.0          0         0              0            43.0
# 2022-09-10            0.0          1         0              0            43.0
# 2022-09-11            0.0          1         0              0            43.0
#
# [741 rows x 10 columns]

# %% [markdown]
# ### Correlation and plots

# %% [markdown]
# The data below indicates the negative correlation of pressure and temperature to precipitation, and scatterplots of each average showing need for logistic regression.

# %%
weather_data.corr()["Precipitation"].sort_values(ascending = False)
# Out:
# Precipitation     1.000000
# Humidity_Avg      0.459474
# Dew_Pt_Avg        0.059830
# Wind_Speed_Avg    0.054425
# New Moon          0.040609
# Full Moon         0.019219
# Sunspot_Number   -0.021005
# Third Quarter    -0.079263
# Pressure_Avg     -0.089618
# Temp_Avg         -0.274907
# Name: Precipitation, dtype: float64

# %%
plt.figure(figsize = (5,3))
sns.scatterplot(x = "Pressure_Avg", y = "Precipitation", data = weather_data)
# Out:
# <AxesSubplot:xlabel='Pressure_Avg', ylabel='Precipitation'>

# %%
plt.figure(figsize = (5,3))
sns.scatterplot(x = "Wind_Speed_Avg", y = "Precipitation", data = weather_data)
# Out:
# <AxesSubplot:xlabel='Wind_Speed_Avg', ylabel='Precipitation'>

# %%
plt.figure(figsize = (5,3))
sns.scatterplot(x = "Wind_Speed_Avg", y = "Precipitation", data = weather_data)
# Out:
# <AxesSubplot:xlabel='Wind_Speed_Avg', ylabel='Precipitation'>

# %%
plt.figure(figsize = (5,3))
sns.scatterplot(x = "Humidity_Avg", y = "Precipitation", data = weather_data)
# Out:
# <AxesSubplot:xlabel='Humidity_Avg', ylabel='Precipitation'>

# %%
precip_days = weather_data.loc[weather_data.Precipitation >0]
precip_days
# Out:
#             Temp_Avg  Dew_Pt_Avg  Humidity_Avg  Wind_Speed_Avg  Pressure_Avg  \
# Date
# 2020-09-26      60.0        46.2          63.4             8.0          27.1
# 2020-10-11      50.8        37.3          62.1             6.2          27.1
# 2020-10-25      33.0        12.6          47.3            11.2          27.2
# 2020-11-02      51.7        45.6          81.1             3.1          27.2
# 2020-11-05      53.4        34.3          52.3            11.3          27.0
# ...              ...         ...           ...             ...           ...
# 2022-07-11      83.7        54.6          39.2             5.9          27.1
# 2022-07-20      82.3        51.8          37.3             7.0          26.9
# 2022-08-03      75.7        45.0          32.9             5.7          27.0
# 2022-08-11      83.7        54.6          39.2             5.9          27.1
# 2022-08-20      82.3        51.8          37.3             7.0          26.9
#
#             Precipitation  Full Moon  New Moon  Third Quarter  Sunspot_Number
# Date
# 2020-09-26            1.0          0         0              0             0.0
# 2020-10-11            1.0          0         0              1            20.0
# 2020-10-25            1.0          0         0              0            19.0
# 2020-11-02            1.0          1         0              0             9.0
# 2020-11-05            1.0          1         0              0            31.0
# ...                   ...        ...       ...            ...             ...
# 2022-07-11            1.0          0         0              0           125.0
# 2022-07-20            1.0          0         0              1           133.0
# 2022-08-03            1.0          0         1              0            37.0
# 2022-08-11            1.0          1         0              0            72.0
# 2022-08-20            1.0          0         0              1            74.0
#
# [154 rows x 10 columns]

# %% [markdown]
# ### Logistic Regression

# %%
X = weather_data.drop("Precipitation", axis = 1)
X
# Out:
#             Temp_Avg  Dew_Pt_Avg  Humidity_Avg  Wind_Speed_Avg  Pressure_Avg  \
# Date
# 2020-09-01      66.8        41.3          42.6             5.8          27.1
# 2020-09-02      76.3        41.9          32.8             6.0          27.1
# 2020-09-03      77.4        40.5          28.3             6.4          27.1
# 2020-09-04      82.2        37.9          23.3             7.2          27.1
# 2020-09-05      82.6        38.2          22.1             7.2          27.1
# ...              ...         ...           ...             ...           ...
# 2022-09-07      85.7        39.1          21.4             8.6          27.0
# 2022-09-08      73.8        30.6          26.1            10.6          27.0
# 2022-09-09      62.4        25.7          27.4             4.4          27.0
# 2022-09-10      66.4        27.1          23.8             7.6          27.1
# 2022-09-11      70.3        27.9          22.8             6.6          27.1
#
#             Full Moon  New Moon  Third Quarter  Sunspot_Number
# Date
# 2020-09-01          1         0              0             0.0
# 2020-09-02          1         0              0             0.0
# 2020-09-03          1         0              0             0.0
# 2020-09-04          1         0              0             0.0
# 2020-09-05          1         0              0             0.0
# ...               ...       ...            ...             ...
# 2022-09-07          0         0              0            43.0
# 2022-09-08          0         0              0            43.0
# 2022-09-09          0         0              0            43.0
# 2022-09-10          1         0              0            43.0
# 2022-09-11          1         0              0            43.0
#
# [741 rows x 9 columns]

# %%
y = weather_data["Precipitation"]
y
# Out:
# Date
# 2020-09-01    0.0
# 2020-09-02    0.0
# 2020-09-03    0.0
# 2020-09-04    0.0
# 2020-09-05    0.0
#              ...
# 2022-09-07    0.0
# 2022-09-08    0.0
# 2022-09-09    0.0
# 2022-09-10    0.0
# 2022-09-11    0.0
# Name: Precipitation, Length: 741, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)
...

# %%
scaler = StandardScaler()

# %%
scaled_X_train = scaler.fit_transform(X_train)

# %%
scaled_X_test = scaler.transform(X_test)

# %%
y_test
# Out:
# Date
# 2021-10-20    0.0
# 2021-11-14    0.0
# 2021-08-06    0.0
# 2021-07-21    1.0
# 2022-01-08    1.0
#              ...
# 2022-06-14    0.0
# 2021-03-03    0.0
# 2022-08-15    0.0
# 2021-07-15    0.0
# 2022-05-18    0.0
# Name: Precipitation, Length: 149, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model = LogisticRegression()

# %%
np.any(np.isnan(weather_data))
# Out:
# True

# %%
np.all(np.isfinite(weather_data))
# Out:
# False

# %%
log_model.fit(scaled_X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16876/1894607122.py in <module>
# ----> 1 log_model.fit(scaled_X_train, y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1342             _dtype = [np.float64, np.float32]
#    1343
# -> 1344         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     882     else:
#     883         y = column_or_1d(y, warn=True)
# --> 884         _assert_all_finite(y)
#     885     if y_numeric and y.dtype.kind == 'O':
#     886         y = y.astype(np.float64)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     101                 not allow_nan and not np.isfinite(X).all()):
#     102             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# --> 103             raise ValueError(
#     104                     msg_err.format
#     105                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
y_pred_pr = log_model.predict_proba(scaled_X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16876/2755070917.py in <module>
# ----> 1 y_pred_pr = log_model.predict_proba(scaled_X_test)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in predict_proba(self, X)
#    1461             where classes are ordered as they are in ``self.classes_``.
#    1462         """
# -> 1463         check_is_fitted(self)
#    1464
#    1465         ovr = (self.multi_class in ["ovr", "warn"] or
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1096
#    1097     if not attrs:
# -> 1098         raise NotFittedError(msg % {'name': type(estimator).__name__})
#    1099
#    1100
#
# NotFittedError: This LogisticRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
y_pred_pr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16876/952325973.py in <module>
# ----> 1 y_pred_pr
#
# NameError: name 'y_pred_pr' is not defined

# %%
log_model.coef_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16876/2024648117.py in <module>
# ----> 1 log_model.coef_
#
# AttributeError: 'LogisticRegression' object has no attribute 'coef_'

# %% [markdown]
# The log_model.coef indicates that for each feature, the corresponding coefficient indicates the probability that there would be precipitation, i.e if Temp_Avg rises by 1 unit, the probability of precipitation decreases, if Dew_Pt_Average increases by 1 unit, the probability of precipitation increases, and so on for each feature.¶

# %%
X.columns
# Out:
# Index(['Temp_Avg', 'Dew_Pt_Avg', 'Humidity_Avg', 'Wind_Speed_Avg',
#        'Pressure_Avg', 'Full Moon', 'New Moon', 'Third Quarter',
#        'Sunspot_Number'],
#       dtype='object')

# %%
X_test
# Out:
#             Temp_Avg  Dew_Pt_Avg  Humidity_Avg  Wind_Speed_Avg  Pressure_Avg  \
# Date
# 2021-10-20      60.4        33.5          37.2            11.0          27.0
# 2021-11-14      52.9        42.1          67.5             8.2          27.2
# 2021-08-06      73.5        49.0          42.8            10.0          27.0
# 2021-07-21      79.7        53.2          43.9             9.8          26.9
# 2022-01-08      34.3        23.6          65.7             5.3          27.2
# ...              ...         ...           ...             ...           ...
# 2022-06-14      51.1        32.3          48.5             8.8          27.1
# 2021-03-03      43.8        24.3          49.2             6.7          26.9
# 2022-08-15      79.7        38.5          25.3             5.0          27.0
# 2021-07-15      84.4        37.5          19.7             7.3          26.9
# 2022-05-18      62.7        34.6          37.5             5.8          27.1
#
#             Full Moon  New Moon  Third Quarter  Sunspot_Number
# Date
# 2021-10-20          1         0              0            12.0
# 2021-11-14          0         0              0            20.0
# 2021-08-06          0         0              1             8.0
# 2021-07-21          0         0              0            72.0
# 2022-01-08          0         1              0            44.0
# ...               ...       ...            ...             ...
# 2022-06-14          1         0              0           122.0
# 2021-03-03          1         0              0            35.0
# 2022-08-15          1         0              0           111.0
# 2021-07-15          0         1              0            22.0
# 2022-05-18          1         0              0           131.0
#
# [149 rows x 9 columns]

# %% [markdown]
# ### Regression metrics¶

# %%
from sklearn.metrics import classification_report

# %% [markdown]
# This report gives the probability of a 1 in the precipitation column using three different categories - precision, recall and f1-score. Precision is accuracy, recall is ratio of class to total, f1 score is mean of precision & recall.

# %%
y_pred = log_model.predict(scaled_X_test)
y_pred

# %%
print(classification_report(y_test, y_pred))

# %% [markdown]
# ### Visualization

# %% [markdown]
# This chart shows the exact opposite of what I would expect. Pressure and temperature would drop if rain is expected, and this is confirmed by the correlation above. I altered the visualization to show the pressure and temperature in blue at th top, I'm not sure how to fix the negative results

# %%
coeff = list(log_model.coef_[0])
labels = list(X_train.columns)
features = pd.DataFrame()
features['Features'] = labels
features['importance'] = coeff
features.sort_values(by=['importance'], ascending=False, inplace=True)
features['negative'] = features['importance'] < 0
features.set_index('Features', inplace=True)
features.importance.plot(kind='barh', figsize=(11, 6),color = features.negative.map({True: 'blue', False: 'red'}))
plt.xlabel('Importance')
plt.show()
