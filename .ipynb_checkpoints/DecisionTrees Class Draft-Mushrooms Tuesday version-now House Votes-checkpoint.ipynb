# %% [markdown]
# # DecisionTrees Class Draft

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import csv
from collections import Counter, defaultdict

# %% [markdown]
# ### Notes about this notebook:
# In this notebook, I tried to put the whole DecisionTree project into one class.  I like this better - it is
# much more logical to me

# %%
df = pd.read_csv("house-votes-84.csv")

# %%
df.head()
# Out:
#    Class Name  handicapped-infants  water-project-cost-sharing  \
# 0  republican                    n                           y
# 1  republican                    n                           y
# 2    democrat                    ?                           y
# 3    democrat                    n                           y
# 4    democrat                    y                           y
#
#    adoption-of-the-budget-resolution  physician-fee-freeze  el-salvador-aid  \
# 0                                  n                     y                y
# 1                                  n                     y                y
# 2                                  y                     ?                y
# 3                                  y                     n                ?
# 4                                  y                     n                y
#
#    religious-groups-in-schools  anti-satellite-test-ban  \
# 0                            y                        n
# 1                            y                        n
# 2                            y                        n
# 3                            y                        n
# 4                            y                        n
#
#    aid-to-nicaraguan-contras  mx-missile  immigration  \
# 0                          n           n            y
# 1                          n           n            n
# 2                          n           n            n
# 3                          n           n            n
# 4                          n           n            n
#
#    synfuels-corporation-cutback  education-spending  superfund-right-to-sue  \
# 0                             ?                   y                       y
# 1                             n                   y                       y
# 2                             y                   n                       y
# 3                             y                   n                       y
# 4                             y                   ?                       y
#
#    crime  duty-free-exports  export-administration-act-south-africa
# 0      y                  n                                       y
# 1      y                  n                                       ?
# 2      y                  n                                       n
# 3      n                  n                                       y
# 4      y                  y                                       y

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.replace('?', np.nan, inplace = True)

# %%
df = df[df.notna().all(axis=1)]

# %%
hand_in = df[" handicapped-infants"]
hand_in.value_counts()
# Out:
# n    136
# y     96
# Name:  handicapped-infants, dtype: int64

# %%
features = list(df.columns)
features
# Out:
# ['Class Name',
#  ' handicapped-infants',
#  ' water-project-cost-sharing',
#  ' adoption-of-the-budget-resolution',
#  ' physician-fee-freeze',
#  ' el-salvador-aid',
#  ' religious-groups-in-schools',
#  ' anti-satellite-test-ban',
#  ' aid-to-nicaraguan-contras',
#  ' mx-missile',
#  ' immigration',
#  ' synfuels-corporation-cutback',
#  ' education-spending',
#  ' superfund-right-to-sue',
#  ' crime',
#  ' duty-free-exports',
#  ' export-administration-act-south-africa']

# %%
#print(features)

# %%
rows = df.index
print(rows)
# Out:
# Int64Index([  5,   8,  19,  23,  25,  26,  27,  28,  29,  30,
#             ...
#             418, 419, 420, 421, 422, 423, 426, 427, 430, 431],
#            dtype='int64', length=232)

# %%
class DecisionTree():
    def __init__(self, data, features, rows, min_samples_split =2, max_depth = 5, depth = None): 
        self.data = data 
        self.features = list(self.data.columns)
        self.rows = data.index
        self.min_samples_split = min_samples_split
        self.max_depth = max_depth
        self.depth = depth
        self.counts = Counter()
        self.root = None
        self.child = None
        
    def __repr__(self): #Pronounced "wrapper" if we print the object it should print the following string
        return "DecisionTree(file = {}, X = {}, y = {})".format(self.data, self.featires, self.rows)
            
    def class_size(self):
        #This version will return the class size of the two classes p and e
        class_size = self.data.groupby(self.rows).size()/len(self.data)
        return class_size
        print(class_size)
    
    #Get proportions of data
    def proportions(df):
    t =len(self.data)
    self.data.groupby(self.features[0]).size()/t
        
    #GINI formula:  g(x) = 1-(x**2 + (1-x)**2)
    def gini(self):
        t = len(self.data)
        p = self.data.groupby(self.features[0]).size()/t
        return 1- sum(p **2)
    
    #Entropy formula H(x) = -(x log_2(x) + (1-x) log_2(1-x)) /// 1/2 H(x)
    def entropy(self):
        t = len(self.data)
        p = self.data.groupby(self.features[0]).size()/t
        return - sum(p*np.log(p.values))
    
    #Define subset for gini calculation
    def subframe(self):
        groups, keys = self.data.groupby[self.X].groups,keys()
        return groups, keys 
    
    #Gets the keys for one feature
    def one_feature(self, data, feature):
        dict_groups_keys = self.data.groupby(self.feature).groups.keys()
        return dict_groups_keys
        
    #GINI for one individual feature. Subf is a subfield (or feature)
    def gini_one_feature(self, data, feature):
        for k, subf in self.groupby(self.feature):
            return k, gini(subf) 
    
    #Calculate gini impurity for that subset   #property is like "cap-color")
    def gini_impurity(self, property):
        s = 0
        for keys, subf in self.data.groupby(property):
            g = gini(subf)
            s += g*len(subf)/len(self.data)
            return s
        
    #Calculate gini impurity for multiple subsets
    def gini_impurities(self, data):
        a = []
        for f in features[1:]:
            a.append([f, impurity(self.data, f)])
            a.sort(key-lambda t: t[1])
        return a

    #Count elements
    def count_elements(self, X):
        n = "number of observations"
        y1 = "number of first class elements"
        y2 = "number of second class elements"
        x = "numeric observations"
        
        #Insuring the correct type
        if y1_count is None:
            y1_count = 0
            
        if y2_count is None:
            y2_count = 0
            
        n = y1_count + y2_count
        
        #If n is 0, then return lowest possible gini impurity
        if n == 0:
            return 0.0
        
        #Getting the probability for each  of the classes
        p1 = y1_count /n
        p2 = y2_count /n
            
    #Compare gini impurity for subset with data.gini
    def compare_impurity(self, gini, impurity):
        return gini - impurity
        
    #Check if a leaf node - stop there   
    def is_leaf_node(self):
        if impurity == 0 or depth >= self.max_depth:
            return True
    
    #Information gain
    def info_gain_root(self):
        # parent node
        self.root = self.impurities.min()
        #best_gain
        best_gain = self.root - impurities
        return best_gain
        
    def info_gain(self):
        #child node
        self.child = self.impurities()
        best_gain = self.child - impurities
        return best_gain
   
    #Splitting criteria
    def split_criteria(self, X, y):
        if gain > best_gain:
            best_gain = gain
            return 
    
    #Generate split
    def _split(self, X_column, split):
        left_idxs = "fill in this"
        right_idxs = "fill in this"
        return left_idxs, rigth_idxs
        #Have to know when to stop and what is in the tree node 
        
    def _traverse_tree(self, x, node):
        if node.is_leaf_node():
            return node.value
        if X.feature > 0.5:
            return (x, left)
        return self._traverse_tree(x, node.right)
    
    def predict(self, X):
        #traverse tree -This is a recursive function
        return np.array([self._traverse_tree(x, self.root) for x in X])
    
    
    #Grow tree  #An array of arrays pointer is a memory location, it finds the memory location.  an array is 
    #sequential.  Linked list don't have next to each other, but pointr to memory location, list linked by pointers
    #Pointer not available in Python, but can simulate with array - leftmost object in array is root node  It will use 
    #all the functions in the class to build the tree
    def grow_tree(self,       ):
        #1. Find root node (leftmost node is the root node)
        
        #2. Decide how to split the root node (using splitting criteria)
        
        #3. Split into two child nodes.
        
        #4. Decide if node is a leaf node.  Stop 
            traverse_tree
        #5. If node is not a leaf node repeat 2, 3, 4.
        
        #6. Predict
        

     
                                     
   
    #Repeat steps from subframe to leaf node for other child nodes

# %% [markdown]
# #### Making the Decision Tree Class
# I would like to get the csv from within the class but can't seem to do it.  I put the root node into
# the attributes but see above about this.  I don't have a code for how to grow the tree

# %%
def proportions(df):
    t =len(df)
    df.groupby("Class Name").size()/t

# %%
#GINI calculation for total dataset
def gini(df):
    t = len(df)
    p = df.groupby("Class Name").size()/t
    return 1 - sum(p **2)

# %%
#This is gini of total dataset
gini(df)
# Out:
# 0.49762187871581454

# %% [markdown]
# #### Root node
# I found this for hyperparameters to use in getting the root node, but I'm not sure how to apply it

# %%
hp = {"max_depth": 3, "min_samples": 50}
hp
# Out:
# {'max_depth': 3, 'min_samples': 50}

# %%
root = DecisionTree(Y, X, **hp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6484/1509708498.py in <module>
# ----> 1 root = DecisionTree(Y, X, **hp)
#
# TypeError: __init__() got an unexpected keyword argument 'min_samples'

# %%
tree1 = DecisionTree(df, X, Y, 100) # instantiation

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
#tree1  #Why does node give this output, where is the repr

# %%
tree1.class_size()
# Out:
# Class Name
# democrat      0.534483
# republican    0.465517
# dtype: float64

# %%
tree1.data
# Out:
#      Class Name  handicapped-infants  water-project-cost-sharing  \
# 5      democrat                    n                           y
# 8    republican                    n                           y
# 19     democrat                    y                           y
# 23     democrat                    y                           y
# 25     democrat                    y                           n
# ..          ...                  ...                         ...
# 423    democrat                    n                           y
# 426    democrat                    y                           n
# 427  republican                    n                           n
# 430  republican                    n                           n
# 431    democrat                    n                           n
#
#      adoption-of-the-budget-resolution  physician-fee-freeze  el-salvador-aid  \
# 5                                    y                     n                y
# 8                                    n                     y                y
# 19                                   y                     n                n
# 23                                   y                     n                n
# 25                                   y                     n                n
# ..                                 ...                   ...              ...
# 423                                  y                     n                n
# 426                                  y                     n                n
# 427                                  n                     y                y
# 430                                  y                     y                y
# 431                                  y                     n                n
#
#      religious-groups-in-schools  anti-satellite-test-ban  \
# 5                              y                        n
# 8                              y                        n
# 19                             n                        y
# 23                             n                        y
# 25                             n                        y
# ..                           ...                      ...
# 423                            y                        y
# 426                            n                        y
# 427                            y                        y
# 430                            y                        n
# 431                            n                        y
#
#      aid-to-nicaraguan-contras  mx-missile  immigration  \
# 5                            n           n            n
# 8                            n           n            n
# 19                           y           y            n
# 23                           y           y            n
# 25                           y           y            y
# ..                         ...         ...          ...
# 423                          y           y            n
# 426                          y           y            y
# 427                          y           n            y
# 430                          n           y            y
# 431                          y           y            y
#
#      synfuels-corporation-cutback  education-spending  superfund-right-to-sue  \
# 5                               n                   n                       y
# 8                               n                   y                       y
# 19                              y                   n                       n
# 23                              n                   n                       n
# 25                              n                   n                       n
# ..                            ...                 ...                     ...
# 423                             y                   n                       n
# 426                             n                   n                       n
# 427                             n                   y                       y
# 430                             n                   y                       y
# 431                             n                   n                       n
#
#      crime  duty-free-exports  export-administration-act-south-africa
# 5        y                  y                                       y
# 8        y                  n                                       y
# 19       n                  y                                       y
# 23       n                  y                                       y
# 25       n                  y                                       y
# ..     ...                ...                                     ...
# 423      y                  y                                       y
# 426      n                  y                                       y
# 427      y                  n                                       y
# 430      y                  n                                       y
# 431      n                  n                                       y
#
# [232 rows x 17 columns]

# %%
tree1.X
# Out:
#      handicapped-infants  water-project-cost-sharing  \
# 5                      n                           y
# 8                      n                           y
# 19                     y                           y
# 23                     y                           y
# 25                     y                           n
# ..                   ...                         ...
# 423                    n                           y
# 426                    y                           n
# 427                    n                           n
# 430                    n                           n
# 431                    n                           n
#
#      adoption-of-the-budget-resolution  physician-fee-freeze  el-salvador-aid  \
# 5                                    y                     n                y
# 8                                    n                     y                y
# 19                                   y                     n                n
# 23                                   y                     n                n
# 25                                   y                     n                n
# ..                                 ...                   ...              ...
# 423                                  y                     n                n
# 426                                  y                     n                n
# 427                                  n                     y                y
# 430                                  y                     y                y
# 431                                  y                     n                n
#
#      religious-groups-in-schools  anti-satellite-test-ban  \
# 5                              y                        n
# 8                              y                        n
# 19                             n                        y
# 23                             n                        y
# 25                             n                        y
# ..                           ...                      ...
# 423                            y                        y
# 426                            n                        y
# 427                            y                        y
# 430                            y                        n
# 431                            n                        y
#
#      aid-to-nicaraguan-contras  mx-missile  immigration  \
# 5                            n           n            n
# 8                            n           n            n
# 19                           y           y            n
# 23                           y           y            n
# 25                           y           y            y
# ..                         ...         ...          ...
# 423                          y           y            n
# 426                          y           y            y
# 427                          y           n            y
# 430                          n           y            y
# 431                          y           y            y
#
#      synfuels-corporation-cutback  education-spending  superfund-right-to-sue  \
# 5                               n                   n                       y
# 8                               n                   y                       y
# 19                              y                   n                       n
# 23                              n                   n                       n
# 25                              n                   n                       n
# ..                            ...                 ...                     ...
# 423                             y                   n                       n
# 426                             n                   n                       n
# 427                             n                   y                       y
# 430                             n                   y                       y
# 431                             n                   n                       n
#
#      crime  duty-free-exports  export-administration-act-south-africa
# 5        y                  y                                       y
# 8        y                  n                                       y
# 19       n                  y                                       y
# 23       n                  y                                       y
# 25       n                  y                                       y
# ..     ...                ...                                     ...
# 423      y                  y                                       y
# 426      n                  y                                       y
# 427      y                  n                                       y
# 430      y                  n                                       y
# 431      n                  n                                       y
#
# [232 rows x 16 columns]

# %%
X
# Out:
#      handicapped-infants  water-project-cost-sharing  \
# 5                      n                           y
# 8                      n                           y
# 19                     y                           y
# 23                     y                           y
# 25                     y                           n
# ..                   ...                         ...
# 423                    n                           y
# 426                    y                           n
# 427                    n                           n
# 430                    n                           n
# 431                    n                           n
#
#      adoption-of-the-budget-resolution  physician-fee-freeze  el-salvador-aid  \
# 5                                    y                     n                y
# 8                                    n                     y                y
# 19                                   y                     n                n
# 23                                   y                     n                n
# 25                                   y                     n                n
# ..                                 ...                   ...              ...
# 423                                  y                     n                n
# 426                                  y                     n                n
# 427                                  n                     y                y
# 430                                  y                     y                y
# 431                                  y                     n                n
#
#      religious-groups-in-schools  anti-satellite-test-ban  \
# 5                              y                        n
# 8                              y                        n
# 19                             n                        y
# 23                             n                        y
# 25                             n                        y
# ..                           ...                      ...
# 423                            y                        y
# 426                            n                        y
# 427                            y                        y
# 430                            y                        n
# 431                            n                        y
#
#      aid-to-nicaraguan-contras  mx-missile  immigration  \
# 5                            n           n            n
# 8                            n           n            n
# 19                           y           y            n
# 23                           y           y            n
# 25                           y           y            y
# ..                         ...         ...          ...
# 423                          y           y            n
# 426                          y           y            y
# 427                          y           n            y
# 430                          n           y            y
# 431                          y           y            y
#
#      synfuels-corporation-cutback  education-spending  superfund-right-to-sue  \
# 5                               n                   n                       y
# 8                               n                   y                       y
# 19                              y                   n                       n
# 23                              n                   n                       n
# 25                              n                   n                       n
# ..                            ...                 ...                     ...
# 423                             y                   n                       n
# 426                             n                   n                       n
# 427                             n                   y                       y
# 430                             n                   y                       y
# 431                             n                   n                       n
#
#      crime  duty-free-exports  export-administration-act-south-africa
# 5        y                  y                                       y
# 8        y                  n                                       y
# 19       n                  y                                       y
# 23       n                  y                                       y
# 25       n                  y                                       y
# ..     ...                ...                                     ...
# 423      y                  y                                       y
# 426      n                  y                                       y
# 427      y                  n                                       y
# 430      y                  n                                       y
# 431      n                  n                                       y
#
# [232 rows x 16 columns]

# %%
tree1.y
# Out:
# 5        democrat
# 8      republican
# 19       democrat
# 23       democrat
# 25       democrat
#           ...
# 423      democrat
# 426      democrat
# 427    republican
# 430    republican
# 431      democrat
# Name: Class Name, Length: 232, dtype: object

# %%
Y
# Out:
# 5        democrat
# 8      republican
# 19       democrat
# 23       democrat
# 25       democrat
#           ...
# 423      democrat
# 426      democrat
# 427    republican
# 430    republican
# 431      democrat
# Name: Class Name, Length: 232, dtype: object

# %%
tree1.gini()
# Out:
# 0.49762187871581454

# %%
tree1.entropy()
# Out:
# 0.6907671705264811

# %%
tree1.max_depth
# Out:
# 5

# %% [markdown]
# #### These functions don't work.

# %%
tree1.gini_impurity(" handicapped-infants")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6484/958693552.py in <module>
# ----> 1 tree1.gini_impurity(" handicapped-infants")
#
# ~\AppData\Local\Temp/ipykernel_6484/3390005292.py in gini_impurity(self, property)
#      44         impurity = 0
#      45         for keys, subframe in self.data.groupby(property):
# ---> 46             g = gini(subframe)
#      47             avg = g*len(subframe)/len(self.data)
#      48             impurity += avg
#
# NameError: name 'gini' is not defined

# %%
tree1.gini_impurities()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6484/1831696174.py in <module>
# ----> 1 tree1.gini_impurities()
#
# TypeError: gini_impurities() missing 1 required positional argument: 'X'

# %%
tree1.best_gain()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6484/2442932136.py in <module>
# ----> 1 tree1.best_gain()
#
# AttributeError: 'DecisionTree' object has no attribute 'best_gain'
